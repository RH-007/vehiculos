# %% [markdown]
# ## **Neo Autos - CSV / JSON**

# %%
import json
import pandas as pd

# %%
PATH = rf"C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria"

# %%
vehiculo = ["autos"]

categorias = ["camionetas-suv", "sedan", "hatchback", "pick-up", "deportivo"]

unidad = ["nuevos", "seminuevos"]

# %%
ruta = []
for nombre in categorias:
    for tipo in unidad:
        file_path = f"{PATH}/neo_autos_img_{vehiculo[0]}_{nombre}_{tipo}.json"
        print(file_path)# Display the first few rows of the DataFrame
        
        ruta.append(file_path)
# Out:
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_camionetas-suv_nuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_camionetas-suv_seminuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_sedan_nuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_sedan_seminuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_hatchback_nuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_hatchback_seminuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_pick-up_nuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_pick-up_seminuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_deportivo_nuevos.json
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_img_autos_deportivo_seminuevos.json

# %%
data_json = []

for ruta_i in ruta:
    with open(ruta_i, 'r', encoding='utf-8') as file:
        data = json.load(file)
        data_json.extend(data)

# %%
len(data_json)
# Out:
# 874

# %%
ruta_salida_img_json = rf"C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\neo_autos_img.json"

print("\nGenerando archivo JSON...\n")
with open(ruta_salida_img_json, "w", encoding="utf-8") as f:
    json.dump(data_json, f, ensure_ascii=False, indent=2)
# Out:
# Generando archivo JSON...

# %% [markdown]
# ## **Generacion de archivos CSV: Categoria - General**

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
ruta_csv = []

for nombre in categorias:
    for tipo in unidad:
        file_path = f"{PATH}/neo_autos_{vehiculo[0]}_{nombre}_{tipo}.csv"
        print(file_path)# Display the first few rows of the DataFrame
        ruta_csv.append(file_path)
# Out:
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_camionetas-suv_nuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_camionetas-suv_seminuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_sedan_nuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_sedan_seminuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_hatchback_nuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_hatchback_seminuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_pick-up_nuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_pick-up_seminuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_deportivo_nuevos.csv
# C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\categoria/neo_autos_autos_deportivo_seminuevos.csv

# %%
data = []

for ruta_i in ruta_csv:
    df = pd.read_csv(ruta_i, sep="|")
    data.append(df)
    
df_combinado = pd.concat(data, ignore_index=True)

# %%
df_combinado
# Out:
#                               titulo tipo_vehiculo       categoria  \
# 0    Mitsubishi Outlander Sport 2026         autos  camionetas-suv
# 1                Ford Territory 2026         autos  camionetas-suv
# 2                Nissan Qashqai 2025         autos  camionetas-suv
# 3                  Kia Sportage 2024         autos  camionetas-suv
# 4                   Mazda Cx-90 2026         autos  camionetas-suv
# ..                               ...           ...             ...
# 869                      Bmw M4 2017         autos       deportivo
# 870    Mercedes Benz Cla 45 Amg 2022         autos       deportivo
# 871                   Bmw M235i 2016         autos       deportivo
# 872                   Bmw M240i 2023         autos       deportivo
# 873                      Bmw M3 2024         autos       deportivo
#
#              marca           modelo     año       precio  \
# 0       Mitsubishi  Outlander Sport  2026.0   US$ 23,990
# 1             Ford        Territory  2026.0   US$ 25,990
# 2           Nissan          Qashqai  2025.0   US$ 31,090
# 3              Kia         Sportage  2024.0   US$ 29,990
# 4            Mazda            Cx-90  2026.0   US$ 54,740
# ..             ...              ...     ...          ...
# 869            BMW               M4  2017.0   US$ 44,400
# 870  Mercedes Benz       Cla 45 Amg  2022.0   US$ 72,990
# 871            BMW            M235i  2016.0   US$ 26,900
# 872            BMW            M240i  2023.0   US$ 55,990
# 873            BMW               M3  2024.0  US$ 110,000
#
#                                                detalle combustible  \
# 0    Gasolina|Automática - Secuencial\nLima, Lima\n...    Gasolina
# 1    Gasolina|Mecánica\nLima, Lima\nPaga El 50% Aho...    Gasolina
# 2    Gasolina|Automática\nLima, Lima\nCompra Tu Pró...    Gasolina
# 3    Gasolina|Automática - Secuencial\nLima, Lima\n...    Gasolina
# 4    Gasolina|Automática\nLima, Lima\nCompra Tu Pró...    Gasolina
# ..                                                 ...         ...
# 869  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 870  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 871  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 872  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 873  Gasolina|Automática\nKilometraje:\n7,600 Kms\n...    Gasolina
#
#     tipo_transmision        caja  kilometraje_km   ubicacion     tags  \
# 0         Automática  Secuencial             NaN  Lima, Lima       []
# 1           Mecánica         NaN             NaN  Lima, Lima  PREMIUM
# 2         Automática         NaN             0.0  Lima, Lima  PREMIUM
# 3         Automática  Secuencial             0.0  Lima, Lima       []
# 4         Automática         NaN             0.0  Lima, Lima  PREMIUM
# ..               ...         ...             ...         ...      ...
# 869       Automática  Secuencial         43000.0  Lima, Lima       []
# 870       Automática  Secuencial         15875.0  Lima, Lima       []
# 871       Automática  Secuencial         48450.0  Lima, Lima       []
# 872       Automática  Secuencial         21000.0  Lima, Lima       []
# 873       Automática         NaN          7600.0  Lima, Lima       []
#
#                                               url_auto        tipo  \
# 0    https://neoauto.com/auto/nuevo/mitsubishi-outl...      nuevos
# 1    https://neoauto.com/auto/nuevo/ford-territory-...      nuevos
# 2    https://neoauto.com/auto/nuevo/nissan-qashqai-...      nuevos
# 3    https://neoauto.com/auto/nuevo/kia-sportage-20...      nuevos
# 4    https://neoauto.com/auto/nuevo/mazda-cx-90-202...      nuevos
# ..                                                 ...         ...
# 869  https://neoauto.com/auto/seminuevo/bmw-m4-2017...  seminuevos
# 870  https://neoauto.com/auto/seminuevo/mercedes-be...  seminuevos
# 871  https://neoauto.com/auto/seminuevo/bmw-m235i-2...  seminuevos
# 872  https://neoauto.com/auto/seminuevo/bmw-m240i-2...  seminuevos
# 873  https://neoauto.com/auto/seminuevo/bmw-m3-2024...  seminuevos
#
#                                                 pagina
# 0    https://neoauto.com/venta-de-autos-nuevos--cam...
# 1    https://neoauto.com/venta-de-autos-nuevos--cam...
# 2    https://neoauto.com/venta-de-autos-nuevos--cam...
# 3    https://neoauto.com/venta-de-autos-nuevos--cam...
# 4    https://neoauto.com/venta-de-autos-nuevos--cam...
# ..                                                 ...
# 869  https://neoauto.com/venta-de-autos-seminuevos-...
# 870  https://neoauto.com/venta-de-autos-seminuevos-...
# 871  https://neoauto.com/venta-de-autos-seminuevos-...
# 872  https://neoauto.com/venta-de-autos-seminuevos-...
# 873  https://neoauto.com/venta-de-autos-seminuevos-...
#
# [874 rows x 17 columns]

# %%
df_combinado["tipo"].value_counts()
# Out:
# tipo
# seminuevos    787
# nuevos         87
# Name: count, dtype: int64

# %%
df_combinado[["titulo", "marca", "tipo","precio", "kilometraje_km", "url_auto"]]
# Out:
#                               titulo          marca        tipo       precio  \
# 0    Mitsubishi Outlander Sport 2026     Mitsubishi      nuevos   US$ 23,990
# 1                Ford Territory 2026           Ford      nuevos   US$ 25,990
# 2                Nissan Qashqai 2025         Nissan      nuevos   US$ 31,090
# 3                  Kia Sportage 2024            Kia      nuevos   US$ 29,990
# 4                   Mazda Cx-90 2026          Mazda      nuevos   US$ 54,740
# ..                               ...            ...         ...          ...
# 869                      Bmw M4 2017            BMW  seminuevos   US$ 44,400
# 870    Mercedes Benz Cla 45 Amg 2022  Mercedes Benz  seminuevos   US$ 72,990
# 871                   Bmw M235i 2016            BMW  seminuevos   US$ 26,900
# 872                   Bmw M240i 2023            BMW  seminuevos   US$ 55,990
# 873                      Bmw M3 2024            BMW  seminuevos  US$ 110,000
#
#      kilometraje_km                                           url_auto
# 0               NaN  https://neoauto.com/auto/nuevo/mitsubishi-outl...
# 1               NaN  https://neoauto.com/auto/nuevo/ford-territory-...
# 2               0.0  https://neoauto.com/auto/nuevo/nissan-qashqai-...
# 3               0.0  https://neoauto.com/auto/nuevo/kia-sportage-20...
# 4               0.0  https://neoauto.com/auto/nuevo/mazda-cx-90-202...
# ..              ...                                                ...
# 869         43000.0  https://neoauto.com/auto/seminuevo/bmw-m4-2017...
# 870         15875.0  https://neoauto.com/auto/seminuevo/mercedes-be...
# 871         48450.0  https://neoauto.com/auto/seminuevo/bmw-m235i-2...
# 872         21000.0  https://neoauto.com/auto/seminuevo/bmw-m240i-2...
# 873          7600.0  https://neoauto.com/auto/seminuevo/bmw-m3-2024...
#
# [874 rows x 6 columns]

# %%
df_combinado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   titulo            874 non-null    object
#  1   tipo_vehiculo     874 non-null    object
#  2   categoria         874 non-null    object
#  3   marca             874 non-null    object
#  4   modelo            874 non-null    object
#  5   año               869 non-null    float64
#  6   precio            874 non-null    object
#  7   detalle           874 non-null    object
#  8   combustible       874 non-null    object
#  9   tipo_transmision  874 non-null    object
#  10  caja              345 non-null    object
#  11  kilometraje_km    852 non-null    float64
#  12  ubicacion         874 non-null    object
#  13  tags              874 non-null    object
#  14  url_auto          874 non-null    object
#  15  tipo              874 non-null    object
#  16  pagina            874 non-null    object
# dtypes: float64(2), object(15)
# memory usage: 116.2+ KB

# %%
df_combinado["kilometraje_km"] = df_combinado["kilometraje_km"].replace(np.nan, 0)

# %%
df_combinado["precio"] = df_combinado["precio"]\
    .str.replace("$", "", regex=False)\
    .str.replace(",", "", regex=False)\
    .str.replace("US", "", regex=False)\
    .str.replace("Consultar", "0", regex=False)\
    .astype(float)

# %%
labels_precio = [ "menor a $5K", "$5K - $10K", "$10K - $20K", "$20K - $30K", "$30K - $40K", "$40K - $50K","$50K a más"]

df_combinado["precio_etiqueta"] = pd.cut(
    df_combinado["precio"],
    bins=[-1, 5000, 10000, 20000, 30000, 40000, 50000, float('inf')],
    labels=labels_precio
    )

# %%
df_combinado["precio_etiqueta"].value_counts()
# Out:
# precio_etiqueta
# $20K - $30K    258
# $10K - $20K    232
# $50K a más     178
# $30K - $40K    124
# $40K - $50K     77
# $5K - $10K       4
# menor a $5K      1
# Name: count, dtype: int64

# %%
df_combinado.columns
# Out:
# Index(['titulo', 'tipo_vehiculo', 'categoria', 'marca', 'modelo', 'año',
#        'precio', 'detalle', 'combustible', 'tipo_transmision', 'caja',
#        'kilometraje_km', 'ubicacion', 'tags', 'url_auto', 'tipo', 'pagina',
#        'precio_etiqueta'],
#       dtype='object')

# %%
df_combinado
# Out:
#                               titulo tipo_vehiculo       categoria  \
# 0    Mitsubishi Outlander Sport 2026         autos  camionetas-suv
# 1                Ford Territory 2026         autos  camionetas-suv
# 2                Nissan Qashqai 2025         autos  camionetas-suv
# 3                  Kia Sportage 2024         autos  camionetas-suv
# 4                   Mazda Cx-90 2026         autos  camionetas-suv
# ..                               ...           ...             ...
# 869                      Bmw M4 2017         autos       deportivo
# 870    Mercedes Benz Cla 45 Amg 2022         autos       deportivo
# 871                   Bmw M235i 2016         autos       deportivo
# 872                   Bmw M240i 2023         autos       deportivo
# 873                      Bmw M3 2024         autos       deportivo
#
#              marca           modelo     año    precio  \
# 0       Mitsubishi  Outlander Sport  2026.0   23990.0
# 1             Ford        Territory  2026.0   25990.0
# 2           Nissan          Qashqai  2025.0   31090.0
# 3              Kia         Sportage  2024.0   29990.0
# 4            Mazda            Cx-90  2026.0   54740.0
# ..             ...              ...     ...       ...
# 869            BMW               M4  2017.0   44400.0
# 870  Mercedes Benz       Cla 45 Amg  2022.0   72990.0
# 871            BMW            M235i  2016.0   26900.0
# 872            BMW            M240i  2023.0   55990.0
# 873            BMW               M3  2024.0  110000.0
#
#                                                detalle combustible  \
# 0    Gasolina|Automática - Secuencial\nLima, Lima\n...    Gasolina
# 1    Gasolina|Mecánica\nLima, Lima\nPaga El 50% Aho...    Gasolina
# 2    Gasolina|Automática\nLima, Lima\nCompra Tu Pró...    Gasolina
# 3    Gasolina|Automática - Secuencial\nLima, Lima\n...    Gasolina
# 4    Gasolina|Automática\nLima, Lima\nCompra Tu Pró...    Gasolina
# ..                                                 ...         ...
# 869  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 870  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 871  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 872  Gasolina|Automática - Secuencial\nKilometraje:...    Gasolina
# 873  Gasolina|Automática\nKilometraje:\n7,600 Kms\n...    Gasolina
#
#     tipo_transmision        caja  kilometraje_km   ubicacion     tags  \
# 0         Automática  Secuencial             0.0  Lima, Lima       []
# 1           Mecánica         NaN             0.0  Lima, Lima  PREMIUM
# 2         Automática         NaN             0.0  Lima, Lima  PREMIUM
# 3         Automática  Secuencial             0.0  Lima, Lima       []
# 4         Automática         NaN             0.0  Lima, Lima  PREMIUM
# ..               ...         ...             ...         ...      ...
# 869       Automática  Secuencial         43000.0  Lima, Lima       []
# 870       Automática  Secuencial         15875.0  Lima, Lima       []
# 871       Automática  Secuencial         48450.0  Lima, Lima       []
# 872       Automática  Secuencial         21000.0  Lima, Lima       []
# 873       Automática         NaN          7600.0  Lima, Lima       []
#
#                                               url_auto        tipo  \
# 0    https://neoauto.com/auto/nuevo/mitsubishi-outl...      nuevos
# 1    https://neoauto.com/auto/nuevo/ford-territory-...      nuevos
# 2    https://neoauto.com/auto/nuevo/nissan-qashqai-...      nuevos
# 3    https://neoauto.com/auto/nuevo/kia-sportage-20...      nuevos
# 4    https://neoauto.com/auto/nuevo/mazda-cx-90-202...      nuevos
# ..                                                 ...         ...
# 869  https://neoauto.com/auto/seminuevo/bmw-m4-2017...  seminuevos
# 870  https://neoauto.com/auto/seminuevo/mercedes-be...  seminuevos
# 871  https://neoauto.com/auto/seminuevo/bmw-m235i-2...  seminuevos
# 872  https://neoauto.com/auto/seminuevo/bmw-m240i-2...  seminuevos
# 873  https://neoauto.com/auto/seminuevo/bmw-m3-2024...  seminuevos
#
#                                                 pagina precio_etiqueta
# 0    https://neoauto.com/venta-de-autos-nuevos--cam...     $20K - $30K
# 1    https://neoauto.com/venta-de-autos-nuevos--cam...     $20K - $30K
# 2    https://neoauto.com/venta-de-autos-nuevos--cam...     $30K - $40K
# 3    https://neoauto.com/venta-de-autos-nuevos--cam...     $20K - $30K
# 4    https://neoauto.com/venta-de-autos-nuevos--cam...      $50K a más
# ..                                                 ...             ...
# 869  https://neoauto.com/venta-de-autos-seminuevos-...     $40K - $50K
# 870  https://neoauto.com/venta-de-autos-seminuevos-...      $50K a más
# 871  https://neoauto.com/venta-de-autos-seminuevos-...     $20K - $30K
# 872  https://neoauto.com/venta-de-autos-seminuevos-...      $50K a más
# 873  https://neoauto.com/venta-de-autos-seminuevos-...      $50K a más
#
# [874 rows x 18 columns]

# %%
cols_obj = ["titulo", "tipo", "categoria", "marca", "modelo", "año", "kilometraje_km",
            "precio", "precio_etiqueta", "tipo_transmision", "caja","detalle",
            "tags","ubicacion", "url_auto"]

data_final = df_combinado[cols_obj]

data_final["tipo"].replace({"nuevos":"nuevo", "seminuevo":"seminuevo"}, inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3652\2859661320.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_final["tipo"].replace({"nuevos":"nuevo", "seminuevo":"seminuevo"}, inplace=True)
# C:\Users\PC\AppData\Local\Temp\ipykernel_3652\2859661320.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_final["tipo"].replace({"nuevos":"nuevo", "seminuevo":"seminuevo"}, inplace=True)

# %%
data_final["tags"] = data_final["tags"].replace({
    "[]":"",})
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3652\161428809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_final["tags"] = data_final["tags"].replace({

# %%
data_final["año"].value_counts()
# Out:
# año
# 2023.0    146
# 2024.0    141
# 2025.0    113
# 2022.0     96
# 2018.0     62
# 2020.0     60
# 2019.0     53
# 2021.0     49
# 2026.0     32
# 2016.0     30
# 2017.0     29
# 2015.0     21
# 2014.0      9
# 2011.0      6
# 2013.0      6
# 2012.0      5
# 1981.0      3
# 2010.0      2
# 2008.0      2
# 2005.0      1
# 2009.0      1
# 1983.0      1
# 1985.0      1
# Name: count, dtype: int64

# %%
ruta_salida_csv = rf"C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\neo_autos_categoria.csv"

data_final.to_csv(ruta_salida_csv, index=False, sep="|", encoding="utf-8-sig")

# %%
ruta_salida_xlsx = rf"C:\Users\PC\Desktop\Proyectos\Proyectos_Py\7.Analisis_Autos\vehiculos\data\neo_autos_categoria.xlsx"

data_final.to_excel(ruta_salida_xlsx, index=False)
